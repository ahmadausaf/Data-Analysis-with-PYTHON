# %%
import numpy as np

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# 1. SIMPLE PLOT WITH 4 NUMBERS

# %%
plt.plot([1, 3, 2, 4])
plt.show()

# %% [markdown]
# 2. Points have X and Y values; Add tiles and Axis Labels

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.title('Test PLot', fontsize=8, color='g')
plt.xlabel('number n')
plt.ylabel('n^2')
plt.show()

# %% [markdown]
# 3. Change figure size. plot red dots; set axis scales:

# %%
plt.figure(figsize=(2,5))
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')
plt.axis([0, 6, 0, 20])
plt.annotate('square it', (3,6))
plt.show()

# %% [markdown]
# 4. BAR CHARTS WITH 4 BARS

# %%
plt.clf()       # clear figure
x = np.arange(4)
y = [8.8, 7.2, 4.5, 6.9]
plt.xticks(x, ('AUSAF', 'AYUSH', 'ANIMESH', 'ANKUR'))
plt.bar(x, y, color=[ 'lime', 'r', 'k', 'tan' ])
plt.show()

# %% [markdown]
# 5. TIME SERIES

# %%
# Time series data source: fpp pacakge in R.
import matplotlib.pyplot as plt
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/a10.csv', parse_dates=['date'], index_col='date')

# Draw Plot
def plot_df(df, x, y, title="", xlabel='Date', ylabel='Value', dpi=100):
    plt.figure(figsize=(16,5), dpi=dpi)
    plt.plot(x, y, color='tab:red')
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.show()

plot_df(df, x=df.index, y=df.value, title='Monthly anti-diabetic drug sales in Australia from 1992 to 2008.')

# %% [markdown]
# 6. RANDOM DOTS IN A SCATTER

# %%
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
sizes = (30* np.random.rand(N))**2
plt.scatter(x, y, s=sizes, c=colors, alpha=0.5)
plt.show()

# %% [markdown]
# 7. HISTOGRAM

# %%
x = [1,1,2,3,3,5,7,8,9,10,
     10,11,11,13,13,17,18,18,
     18,19,20,21,21,23,24,24,25,25,
     25,25,26,26,267,27,27,
     29,30,30,31,33,34,4,35,36,
     36,37,37,38,38,39,40,41,41,42,
     43,44,45,45,46,70,47,48,48,49,50,
     51,52,53,54,58,60,59,55,
     61,63,64,65,66,68,70,71,72,74,
     75,77,81,83,84,87,89,90,90,91
     ]

plt.hist(x, bins=10)
plt.show()

# %% [markdown]
# 8. PIE CHART

# %%
labels = 'COVID', 'EBOLA', 'POLIO', 'INFLUENZA'
sizes = [215, 130, 245, 210]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.1, 0, 0, 0)  # explode 1st slice

# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.show()

# %%
fig = plt.figure()
ax1 = fig.add_axes([0.1, 0.5, 0.8, 0.4],
                   xticklabels=[], ylim=(-1.2, 1.2))
ax2 = fig.add_axes([0.1, 0.1, 0.8, 0.4],
                   ylim=(-1.2, 1.2))

x = np.linspace(0, 10)
ax1.plot(np.sin(x))
ax2.plot(np.cos(x));
